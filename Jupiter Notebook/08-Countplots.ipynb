# %%
#  steps for dATA visuAlizAtion
# step1:  import libraRIES
import seaborn as sns
import matplotlib.pyplot as plt
# setp2:  SET a THEME
sns.set_theme(style="dark", color_codes=True) 
#  step3:  import data SET]   yOU CaN IMPORT YOUR OWN DaTa aLSO
kashti = sns.load_dataset("titanic")
# print(kashti)
  #step4:  Plot basic Graph (count plot with one vAriAble)
# p=sns.countplot(x= "sex",data=kashti)#you don't need to describe  y Axis becAuse countplt do this func. itself
plt.show()
 #step5:  Plot basic Graph(countplot with two vAriAble)   #you've to mention hue,(color)
# p=sns.countplot(x= "sex",data=kashti, hue="class")
# plt.show()
#strp6:  Plot basic Graph(countplot with two vAriAble)   , with title
p=sns.countplot(x="sex",data=kashti,hue="class")
p.set_title("my first countplot grAph")
plt.show()
