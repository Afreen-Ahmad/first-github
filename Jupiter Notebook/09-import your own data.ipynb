# %%
#pip install pandas
#importing libraries
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# Load data from file using Pandas
dataset=pd.read_csv("data_cleaned.csv",sep=",")
#dataset.head()

#_Plot a graph of based on your data
            # <<<Both the arguments should be numeric>> other wise it will not work
dataset.plot(kind='scatter',x="Your Weight in kg? (float)",
             y="How many hours you code a day? (int) e.g: 5,4,3")
           #data=dataset
# Out:
# <AxesSubplot:xlabel='Your Weight in kg? (float)', ylabel='How many hours you code a day? (int) e.g: 5,4,3'>

# %%
dataset
# Out:
#      Gender  Location    Age Qualification_completed    field_of_study  \
# 0      Male  Pakistan  36-40                 Masters  Natural Sciences
# 1      Male  Pakistan  26-30               Bachelors             CS/IT
# 2      Male  Pakistan  31-35                 Masters       Enginnering
# 3    Female  Pakistan  31-35                 Masters             CS/IT
# 4    Female  Pakistan  26-30                 Masters       Enginnering
# ..      ...       ...    ...                     ...               ...
# 370    Male  Pakistan  26-30                 Masters       Enginnering
# 371    Male  Pakistan  31-35               Bachelors       Enginnering
# 372    Male  Pakistan  21-25               Bachelors             CS/IT
# 373    Male  Pakistan  26-30                 Masters       Enginnering
# 374  Female  Pakistan  31-35                 Masters       Mathematics
#
#            Purpose_for_chilla What are you? Blood group   \
# ...

# %% [markdown]
# # Hist Graph

# %%
#pip install pandas

import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
dataset=pd.read_csv("data_cleaned.csv",sep=",")
#dataset.head()
dataset.plot(kind='hist',x="Your Weight in kg? (float)",y="How many hours you code a day? (int) e.g: 5,4,3")
           #data=dataset
# Out:
# <AxesSubplot:ylabel='Frequency'>
