# %% [markdown]
# # Asalaamu Aliekum My Name is Afreen
# ## I'm learning datascientist with Dr Ammar tufail
# ### Riht now we are learning python basics

# %% [markdown]
# # Asalaamu Aliekum
# ## this is the  first programme I've write
# ### learning Datascientist with Dr tufail Ammar

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# # This is the Basics of operators
# we have learned here
# ## Arthematic operators
# ## Assignment operators
# ## Comparison operators

# %%
# Arthemetic operaters  #examples +, -, *, /,   etc.
#Assignment opertions: =, +=, -=  etc
#Comparison operators: ==, <, <=, >, >=, != ec.
#Logicl operators: and or  not
                  #ArthemaTIC OPERaTIONS;
#EXaMPLES
a=23+2
print(a)
b= 22+22
print(b)

                        #aSSIGNMENt oPERaTORs
# Assignment operaters: that operaters through which you can add value to variables
#exmpl:


# similarly we can use"-='', and *= to sub. or multiple a variable
                # comparison operators 
g=(23)
g=(g>2) 
print(g)
# so comparison operators are the operators which shows the function is true or false
# other comparison operations are "==, <,  >,  !=, 
# EXaMple 
A=55==55
print(A)
print(66<67)
print(66>67)
print(54<=53)
print(54>=53)
# QUESTION : write A python programme to find averge of two no.?
#we know the AveAge is equAl to the sum of numbers divided by two..
a= 45
b=5
avg=(a+b)/ 2   # we didn't get the aNswer ??
#write a python to cAlculAte squre of number entered by the user?
a= input("Enter Any number you  wAnt to get squaRE of:-")
a = int(a)
print(a*a)
# Out:
# 25
# 44
# True
# True
# True
# False
# False
# True
# Enter Any number you  wAnt to get squaRE of:-5
# 25

# %% [markdown]
# # Now we are going to learn the basics of strings (In Sha Allah)
#                 # we've learned
#              1. string slicing
#              2.string slicing by skipping value
#              3.some function's about string like:(length, find, count, capatilize, replace)
#              4. we learn some escpe sequences

# %%
                       #all about STRINGS
#primarily strings Are of three types 1. single quAted  2. Double quAted  3. triple quoted
#these were creAted to stAy AwAy from the errors,  As we cAn't use double quoted in single quote it gives error so we've to use double quoted string then only we  cAn use single quoted sentences inside the text. 
#If we'Ve to use double quoted sentences inside the text then we've to stArt text with triple quotes.a


            #STRING SLICING:- A string in python cAn be sliced for getting A pAth of the string
b= "AFREEN" #we cAn execute Any letter from Above vAriAble As:-
print(b[0])
print(b [1])
print(b [2])
print(b [3])
print(b [4])
print(b [5])
   # we cAn print "some letters" from b At a time
print(b[0:5])
print(b[0:7])  # it prints the (n-1)th no. of the string

# we cAn use power operAtor As well:
# print(3**2)#just by using double multiple operAtors.

# if we write An equation to solve it will follow the "PEMDAS"
# P: pArAnthesis, E: Exponents, M: MultiplicAtion, D: Division, A: Addition, S: SubtrAction .
# There will be left to right sequence for  M D & A S.


            #EXERCISE

#shere greetings to A friend

name= input("Enter Your Name:-  ")
ton= ("AsalAAmu Aliekum\n")
greetings= ("warm welcome to you for registration  to our four months 'Religious Sciences' Course, we hope this course will be beneficial to you and you will learn A lot from this course. If there is Any qurery regArding The course please contAc to our mentor.\n")
date= input("Enter date:-   ")
print(ton, name, greetings, "DATE =", date)

                        # STRING SLICING BY SKIPPING VaLUE
b= " Hello My deAr sir i'm your student Are u ok ."
print(b[1: :4])

                  # NOW LETS LEaRN SOME FUNCTIONS aBOUT STRINGS
# 1:- WE cAn know the length of Any string
b = " HeAven"
print(len(b))  

                  # YOU caN COUNT HOW MaNY TIMES  a WORD COMES IN THE STRING BY USING "COUNT FUNCTION"
C = "WE cAn know the length of Any string"
print(c.count("A"))


                  # YOU CaN CaPTILIZE THE FIRST aLPHaBET OF a WORD IN a STRING BY USING "caPaTLIZE FUNCTION"
d="wE cAn know the length of Any string"
print(d.capitalize())


                  # A function Finds A word And returns the index of first OccuRAnce of thAt word in the string.  EG
d="wE cAn know the length of Any string"
print(d.find("Any"))  # Remember it gives Indices of the first Alphabet of word in the string


                  # An Another importAnt function know As replAce function it replAces the old word to the new 
d="wE  know the length of Any string"
print(d.replace("wE", "How CAn we"))


                  #there is An importnt functions clled escApe sequences
                  #exmple for:- new line (\n)   ,for TAb(\t),    for single code(\') ,    for bAck slAsh (\\)
b = "Hello\t my nAme is\n Afreen AhmAd you cAn cAll me \'Afreen Only"
print(b)

                  #E X E R C I S E#
letter = '''Dear 'name'
you are very lucky . I'm very happy to say that you are selected in our company i Am very glad to give u this news congraTulaTions
Date: 'date'
'''
name=input("Enter Name")
date=input("enter date:-")
letter=letter.replace("'name'", name)
letter=letter.replace("'date'",date)
print(letter)
                  # write  A silly exAmple on replace function
freedom= '''MY dear\n 'silly' 
i wAnt to sAy thAt you Are very Silly who Does this before i don't hAve Any ideA I sAw this first time in my life 'kouli pAgli'
'''
silly= input("Enter your nAme :- \n")
freedom=freedom.replace('silly', silly)
print(freedom)


                        # questions 
b = ("Hello My name is  Afreen")
b=b.find("  ")
b= b.replace("  "," ")
print(b)
letter= '''dear Afreen,\n\t your learning classes are very good we get a lot of benefit from it may Allah give you jazaya khair\n\t\t Thankyou!
'''
print(letter)
# Out:
# A
# F
# R
# E
# E
# N
# AFREE
# AFREEN
# Enter Your Name:-  ajay
# Enter date:-   22 33 55
# AsalAAmu Aliekum
#  ajay warm welcome to you for registration  to our four months 'Religious Sciences' Course, we hope this course will be beneficial to you and you will learn A lot from this course. If there is Any qurery regArding The course please contAc to our mentor.
#  DATE = 22 33 55
# Ho rrmutnr .
# 7
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_41324\1467929728.py in <module>
#      46                   # YOU caN COUNT HOW MaNY TIMES  a WORD COMES IN THE STRING BY USING "COUNT FUNCTION"
#      47 C = "WE cAn know the length of Any string"
# ---> 48 print(c.count("A"))
#      49
#      50
#
# NameError: name 'c' is not defined

# %% [markdown]
#                    # Comment's
# comment is basically a key word used by the programming to write up the important points about the code which programmer don't want to execute .
# primarily there are three types of comments :
#     1.single couted comment  ('')
#     2. doubly couted comment(" ")
#     3. triple couted comment (''' ''')
# The need of these three comments is because some times we have to write single couted line to mention something and we can't mention  single cout's in a single couted line.
# so we have to write double couted comment to mention single couted things inside the comment . And  There is same usage of triple couted comment.

# %% [markdown]
# # Conditional Expressions And Logical Operators.

# %%
b= int(input("Enter your Age:- "))
if (b >=18):
      print("congrAtulAtions, Your Are eligble")
elif (b <= 18):   #use elif if you wnt to show Anything on fAiling in eligble crieteriA
      print("sorry you r not eligble")
else :
      print(" sorry we didn't get you")

        
a=  int(input("Enter the digit:-  "))
if(a>90):
      print("The no is greater then .")
elif(a<56):
      print("The number is less than.")
else:
      print("the no. is not defined")
        #if you add another "if condition" then it will be read separately .....


if(a==50):
      print("the no. is defined")
else:
      print("not defined")


            #A quick quiz question
age=int(input("Enter age"))
if age>=18:
      print("yes")
else:
      print("no you are dangerous")

            # Logical Operators
# the "and" logical operator:its is used if you put 2 conditions and you want both should be setisfies
            #EXaMple
b= int(input("Enter Your Age:- "))
if (b <=45 and b >=20):
      print("Hello DeAr you'r eligble you cAn go for further verificAtions")
elif(b > 0 and b <20):
      print(" This content is Age restricted we're reAlly sorry you cAn't go further you cAn wAit till you become 20 yeArs old")
else:
      print("DAfA gAs Your kot AAkh")
#input("Enter FeedbAck:-")
            # Note
# You can use multiple 'elif' elements in if element
#if there is "if" condition with multiple elements "elif" conditions it will be considered one ladder
            
      #  Or
#when you give two conditions in a if statements and there is true one of them it will operate the given print

c = (input("Enter the mobile pAsword"))
if (b== 54321 or b== 8961  or b == 5525 or b==123456789):
      print("your code is correct we Are giving you further detAils......")
elif(b=="AyAn Afreen" or b== "I'm Muslim" or  b== "AllAh is All knowing"):
      print("your code is correct we Are giving you further detAils......")


       # not THE LOGICAL OEPRATOR
# this is the operator which makes your statement vice versa means if your statement is true 
a=int(input("Enter your no."))
if not a<30:
      print("actually you are right")
else:
      print("you are wrong")
#             #2nd exAmple
b = int(input("Enter your MArks in Grphics:-"))
if not b<50 :
      print("You Are fAil")
else:
      print("You Are pAss")


      #    another example :If the result of the statement is non "0" or ture The 'not' operator will turn it into "0"or'false '

            #CHAPTER 6 PRACTICE SET
  #QUESTION NO. 1\n
b=int(input("enter No 1:-"))
c=int(input("enter No 2:-")
d=int(input("enter No 3:-"))
e=int(input("enter No 4:-"))
if (b>c):
      f1= b
else:
      f1=c
#if (d>e):
      f2=d
else:
#       f2=e
if (f1>f2):
      print(str(f1), "Is greAtest Number\n ThAnkyou")
else:
      print(str(f2), "Is greAtest Number\n ThAnkyou")

            #Another ExApmpl
num1=9876555444 
num2=4467898678
num3=9682379991
num4=66566987852
if(num1>num2):
      f1=num1
else:
      f1=num2
if(num3>num4):
      f2=num3
else:
      f2=num4
if(f1>f2):
      print(str(f1) + "  is greatest")
else:
      print(str(f2) + "  is greatest")
                  #QUESTION NO. 2
sub1=int(input("enter subject  1 first marks:-\n"))
sub2=int(input("enter subject 2 first marks:-\n"))
sub3=int(input("enter subject 3 first marks:-\n"))
if(sub1<33 or sub2<33 or sub3<33):
      print("You are failed try again in next year")
elif(sub1+sub2+sub3)/3 <40: # Average
      print("you are failed because your percentage is less than 40")
else:
#       print("Congratulations you have passed the test")
            #QUESTION NO. 3
# text=input("Enter the text")
# if("make a lot of money" in text):
#       spam= True
# elif("buy now" in text):
#       spam= True
# elif("click this" in text):
#       spam= True
# elif(" subscribe" in text):
#       spam= True
# else:
#       spam= False
# if(spam):
#       print("This is spam dear")
# else:
#       print("this is not spam")
                  #QUESTION NO. 4
# a= input("enter your name")
# if(len(a)<10):
#       print("your name is less than 10, Nice")
# else:
#       print("enter 10 characters of your name")

            #QUESTION NO 4
# f=input("enter your name")
# if(len(f)<10):
#       print("ok your name is less than 10 characters.")
# else:
#       print("please enter > 10 characters")

            #QUESTION NO 5'
# list=["afreen","shahid""zahid","usamah", "mehmood"]
# a=input("enter your name")
# if(a in list):
#       print("yes you are in")
# else:
#       print("sorry we cant find your name")
            #QUESTION NO 6
# a=int(input("enter your marks:-\n"))
# if(a>=90):
#       grade="EX"
# elif(a>=80):
#       grade="A"
# elif(a>=70):
#       grade="B"
# elif(a>=60):
#       grade="c"
# elif(a>=50):
#       grade="D"
# else:
# Out:
# Enter your Age:- 34
# congrAtulAtions, Your Are eligble
# Enter the digit:-  44
# The number is less than.
# not defined
# Enter age24
# yes
# Enter Your Age:- 55
# DAfA gAs Your kot AAkh
# Enter the mobile pAswordAyan Afreen
# Enter your no.98
# actually you are right
# Enter your MArks in Grphics:-44
# You Are pAss
