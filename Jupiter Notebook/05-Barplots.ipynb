# %% [markdown]
# #     Countplots (Graphs)

# %%
import seaborn as sns  # we've imported seaborn library(Heat map, timeseries and other plot's)
import matplotlib.pyplot as plt #Here we imported matplotlib(This plot graphs and figures)
sns.set_theme(style="ticks", color_codes=True) #this is for giving styles to graphs you can go to library and check many other styles
plt.figure(figsize=(1,1))
titanic= sns.load_dataset("titanic")  #we used the data which is builtin in seaborn library  #check in google Builtin data sets in seaborn library 
sns.catplot(x="sex", y="survived",hue="class", kind="bar", data=titanic)
plt.show()

# %%
                    #######2ND COPY OF ABOVE CODE########3
import seaborn as sns  # we've imported seaborn library(Heat map, timeseries and other plot's)
import matplotlib.pyplot as plt #Here we imported matplotlib(This plot graphs and figures)
sns.set_theme(style="whitegrid", color_codes=True) #this is for giving styles to graphs you can go to library and check many other styles

titanic= sns.load_dataset("titanic")  #we used the data which is builtin in seaborn library  #check in google Builtin data sets in seaborn library 
sns.catplot(x="sex", y="survived",hue="class", kind="point", data=titanic)
plt.show()

# %%
import seaborn as sns
import matplotlib as plt
sns.set_theme(style="ticks", color_codes=True)
titanic = sns.load_dataset("titanic")
P1=sns.countplot(x="sex", data=titanic, hue='class')
p1.set_title("plot of counting")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7984\2762223138.py in <module>
#       4 titanic = sns.load_dataset("titanic")
#       5 P1=sns.countplot(x="sex", data=titanic, hue='class')
# ----> 6 p1.set_title("plot of counting")
#       7 plt.show()
#
# NameError: name 'p1' is not defined

# %% [markdown]
# #  Scatterplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)
titanic= sns.load_dataset("titanic")
g = sns.FacetGrid(titanic, row="sex",hue="alone")
g=(g.map(plt.scatter,"age","fare").add_legend())
plt.show()
